# %%
# !python -V
# Out:
# Python 3.10.9

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet("../data/yellow_tripdata_2022-01.parquet")

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 3.80         1.0                  N           142
# 1                 2.10         1.0                  N           236
# 2                 0.97         1.0                  N           166
# 3                 1.09         1.0                  N           114
# 4                 4.30         1.0                  N            68
# ...                ...         ...                ...           ...
# 2463926           1.32         NaN               None            90
# 2463927           4.19         NaN               None           107
# 2463928           2.10         NaN               None           113
# 2463929           2.92         NaN               None           148
# 2463930           8.94         NaN               None           186
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 236             1        14.50    3.0      0.5        3.65
# 1                  42             1         8.00    0.5      0.5        4.00
# 2                 166             1         7.50    0.5      0.5        1.76
# 3                  68             2         8.00    0.5      0.5        0.00
# 4                 163             1        23.50    0.5      0.5        3.00
# ...               ...           ...          ...    ...      ...         ...
# 2463926           170             0         8.00    0.0      0.5        2.39
# 2463927            75             0        16.80    0.0      0.5        4.35
# 2463928           246             0        11.22    0.0      0.5        2.00
# 2463929           164             0        12.40    0.0      0.5        0.00
# 2463930           181             0        25.48    0.0      0.5        6.28
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                 0.0                    0.3         21.95
# 1                 0.0                    0.3         13.30
# 2                 0.0                    0.3         10.56
# 3                 0.0                    0.3         11.80
# 4                 0.0                    0.3         30.30
# ...               ...                    ...           ...
# 2463926           0.0                    0.3         13.69
# 2463927           0.0                    0.3         24.45
# 2463928           0.0                    0.3         16.52
# 2463929           0.0                    0.3         15.70
# 2463930           0.0                    0.3         35.06
#
#          congestion_surcharge  airport_fee
# 0                         2.5          0.0
# 1                         0.0          0.0
# 2                         0.0          0.0
# 3                         2.5          0.0
# 4                         2.5          0.0
# ...                       ...          ...
# 2463926                   NaN          NaN
# 2463927                   NaN          NaN
# 2463928                   NaN          NaN
# 2463929                   NaN          NaN
# 2463930                   NaN          NaN
#
# [2463931 rows x 19 columns]

# %%
df.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
df = df[(df.payment_type==1)]
#         & (df.RatecodeID==1)]

# %%
df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds()/60)
# Out:
# /tmp/ipykernel_18331/565802382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
# /tmp/ipykernel_18331/565802382.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.duration = df.duration.apply(lambda td: td.total_seconds()/60)

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# 5               1  2022-01-01 00:40:15   2022-01-01 01:09:48              1.0
# ...           ...                  ...                   ...              ...
# 2392422         1  2022-01-31 23:47:56   2022-02-01 00:04:43              1.0
# 2392424         2  2022-01-31 23:17:44   2022-01-31 23:22:05              1.0
# 2392425         2  2022-01-31 23:26:41   2022-01-31 23:34:54              1.0
# 2392426         2  2022-01-31 23:37:41   2022-01-31 23:45:26              1.0
# 2392427         2  2022-01-31 23:43:22   2022-01-31 23:55:36              1.0
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 3.80         1.0                  N           142
# 1                 2.10         1.0                  N           236
# 2                 0.97         1.0                  N           166
# 4                 4.30         1.0                  N            68
# 5                10.30         1.0                  N           138
# ...                ...         ...                ...           ...
# 2392422           3.30         1.0                  N           234
# 2392424           1.02         1.0                  N           249
# 2392425           1.53         1.0                  N            68
# 2392426           1.59         1.0                  N            90
# 2392427           4.04         1.0                  N           140
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 236             1         14.5    3.0      0.5        3.65
# 1                  42             1          8.0    0.5      0.5        4.00
# 2                 166             1          7.5    0.5      0.5        1.76
# 4                 163             1         23.5    0.5      0.5        3.00
# 5                 161             1         33.0    3.0      0.5       13.00
# ...               ...           ...          ...    ...      ...         ...
# 2392422           236             1         14.5    3.0      0.5        3.00
# 2392424            68             1          5.5    0.5      0.5        1.86
# 2392425            90             1          8.0    0.5      0.5        2.95
# 2392426            79             1          7.5    0.5      0.5        2.26
# 2392427            24             1         13.5    0.5      0.5        3.46
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    0.3         21.95
# 1                0.00                    0.3         13.30
# 2                0.00                    0.3         10.56
# 4                0.00                    0.3         30.30
# 5                6.55                    0.3         56.35
# ...               ...                    ...           ...
# 2392422          0.00                    0.3         21.30
# 2392424          0.00                    0.3         11.16
# 2392425          0.00                    0.3         14.75
# 2392426          0.00                    0.3         13.56
# 2392427          0.00                    0.3         20.76
#
#          congestion_surcharge  airport_fee   duration
# 0                         2.5          0.0  17.816667
# 1                         0.0          0.0   8.400000
# 2                         0.0          0.0   8.966667
# 4                         2.5          0.0  37.533333
# 5                         2.5          0.0  29.550000
# ...                       ...          ...        ...
# 2392422                   2.5          0.0  16.783333
# 2392424                   2.5          0.0   4.350000
# 2392425                   2.5          0.0   8.216667
# 2392426                   2.5          0.0   7.750000
# 2392427                   2.5          0.0  12.233333
#
# [1874874 rows x 20 columns]

# %%
sns.distplot(df.duration)
# Out:
# /tmp/ipykernel_18331/3426635498.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.duration)
# <Axes: xlabel='duration', ylabel='Density'>

# %%
df.duration.describe().round()
# Out:
# count    1874874.0
# mean          14.0
# std           44.0
# min            0.0
# 25%            6.0
# 50%           10.0
# 75%           16.0
# max         1440.0
# Name: duration, dtype: float64

# %%
((df.duration >= 1) & (df.duration <= 60 )).mean()
# Out:
# 0.9896665055891756

# %%
td = df.duration.iloc[0]

# %%
td
# Out:
# 17.816666666666666

# %%
td.total_seconds()/60
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 td.total_seconds()/60
#
# AttributeError: 'numpy.float64' object has no attribute 'total_seconds'

# %%
l1 = ["eat", "sleep", "repeat"]
s1 = "geek"
  
# creating enumerate objects
obj1 = enumerate(l1)
obj2 = enumerate(s1)
  
print ("Return type:", type(obj1))
print (list(enumerate(l1)))
  
# changing start index to 2 from 0
print (list(enumerate(s1, 2)))

# %%
df.duration.describe(percentiles=[0.95, 0.98, 0.99]).round()
# Out:
# count    1874874.0
# mean          14.0
# std           44.0
# min            0.0
# 50%           10.0
# 95%           31.0
# 98%           41.0
# 99%           49.0
# max         1440.0
# Name: duration, dtype: float64

# %%
df.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee', 'duration'],
#       dtype='object')

# %%
df= df[(df.duration >= 1) & (df.duration <= 60 )]

# %%
categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

# %%
df[categorical] = df[categorical].astype(str)
# Out:
# /tmp/ipykernel_18331/1767203464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)
